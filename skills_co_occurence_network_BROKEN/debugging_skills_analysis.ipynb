# %%
import severability
import numpy as np
import pandas as pd

# %%
# read the co-occurrence matrix file
skill_df = pd.read_csv("Lightcast_taxonomy_M2R.csv", index_col=0)

inds = skill_df.index
skills = skill_df['Lightcast_skills'].to_list()
skill_to_ind = {s: i for i, s in enumerate(skills)}

matrix_df = pd.read_csv("Lightcast_co_mat.csv", index_col=0).fillna(0)
matrix_df = matrix_df.iloc[inds, inds]

matrix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3906 entries, Dc.js to Dyeing
# Columns: 3906 entries, Dc.js to Dyeing
# dtypes: float64(3906)
# memory usage: 116.4+ MB

# %%
def keep_top_k_per_row(A: np.ndarray, k: int = 50):
    """
    For each row in A, keep only the k largest values; zero out the rest.
    """
    A_topk = np.zeros_like(A)
    topk_idx = np.argpartition(-A, k, axis=1)[:, :k]
    rows = np.arange(A.shape[0])[:, None]
    A_topk[rows, topk_idx] = A[rows, topk_idx]
    return A_topk

# generate adjacency matrix
A = matrix_df.to_numpy(dtype=np.float32)
A = keep_top_k_per_row(A)

P = severability.transition_matrix(np.matrix(A))

# %%
class Skill:
    def __init__(self, name: str, index: int):
        self.name = name
        self.index = index
        self.sev_series = []

    def __repr__(self):
        return f"Skill(name={self.name}, index={self.index})"
    
    def calculate_components(self, transition, max_size=10):
        for t in range(1, 4):
            comp = severability.node_component(P=transition, i=self.index, t=t, max_size=max_size)
            time_comp = (t, comp)
            self.sev_series.append(time_comp)

# %%
# Load and clean the skills taxonomy
skills = pd.read_csv("Lightcast_taxonomy_M2R.csv", index_col=1)
if 'Unnamed: 0' in skills.columns:
    skills = skills.drop('Unnamed: 0', axis=1)

# Function to get skill:index mapping for a category, filtered by available labels
def get_skills_from_category(category, labels):
    # Get all skills in the category
    category_skills = skills[skills['Category (corrected)'] == category].index
    
    # Intersect with labels (preserves order and position in labels)
    filtered_labels = labels.intersection(category_skills)
        
    # Build mapping: skill_name -> index in labels
    return [ Skill(skill, labels.get_loc(skill)) for skill in filtered_labels ]

tech_skills = get_skills_from_category('Information Technology', matrix_df.columns) + get_skills_from_category('Analysis', matrix_df.columns)
hospitality_skills = get_skills_from_category('Hospitality and Food Services', matrix_df.columns)

len(tech_skills), len(hospitality_skills)
# Out:
# (834, 48)

# %%
tech_skills[1].calculate_components(P)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 tech_skills[1].calculate_components(P)
#
# Cell In[12], line 12, in Skill.calculate_components(self, transition, max_size)
#      10 def calculate_components(self, transition, max_size=10):
#      11     for t in range(1, 4):
# ---> 12         comp = severability.node_component(P=transition, i=self.index, t=t, max_size=max_size)
#      13         time_comp = (t, comp)
#      14         self.sev_series.append(time_comp)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:236, in node_component(P, i, t, max_size)
#     232 n_sorted = sorted(
#     233     neighbors, key=lambda n: -1 * severability_of_component(P, [i, n], t)
#     234 )
#     235 for n in n_sorted:
# --> 236     component, sev = component_optimise(P, [i, n], t, max_size)
#     237     if i in component:
#     238         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:290, in component_optimise(P, C, t, max_size)
#     288     (C, sev) = greedy_remove_step(P, C, t)
#     289 else:
# --> 290     (C, sev) = kernighan_lin_step(P, C, t)
#     291 if sev > sev_max:
#     292     sev_max = sev
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:329, in kernighan_lin_step(P, C, t)
#     325 """if can add a node, will either remove or add a node, optimising sev
#     326 if can't add a node because no neighbors, will either remove a node or stay constant.
#     327 """
#     328 C_add, sev_add = greedy_add_step(P, C, t)
# --> 329 C_rem, sev_rem = greedy_remove_step(P, C, t)
#     330 if sev_add > sev_rem:
#     331     return (C_add, sev_add)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:317, in greedy_remove_step(P, C, t)
#     313 def greedy_remove_step(P, C, t):
#     314     """Greedily removes a node to C such that the new severability is as high
#     315     as possible. Note that a node *will* be removed, even if any removal
#     316     decreases the severability"""
# --> 317     removed_node = max(
#     318         C, key=lambda n: severability_of_component(P, [x for x in C if x != n], t)
#     319     )
#     320     C = [x for x in C if x != removed_node]
#     321     return (C, severability_of_component(P, C, t))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:318, in greedy_remove_step.<locals>.<lambda>(n)
#     313 def greedy_remove_step(P, C, t):
#     314     """Greedily removes a node to C such that the new severability is as high
#     315     as possible. Note that a node *will* be removed, even if any removal
#     316     decreases the severability"""
#     317     removed_node = max(
# --> 318         C, key=lambda n: severability_of_component(P, [x for x in C if x != n], t)
#     319     )
#     320     C = [x for x in C if x != removed_node]
#     321     return (C, severability_of_component(P, C, t))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\severability\severability.py:133, in severability_of_component(P, C, t)
#     131 P_C = P[[[i] for i in C], C]  # Get submatrix
#     132 if t > 1:
# --> 133     P_C_power = P_C**t
#     134 else:
#     135     P_C_power = P_C
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\matrixlib\defmatrix.py:232, in matrix.__pow__(self, other)
#     231 def __pow__(self, other):
# --> 232     return matrix_power(self, other)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:636, in matrix_power(a, n)
#     634 a = asanyarray(a)
#     635 _assert_stacked_2d(a)
# --> 636 _assert_stacked_square(a)
#     638 try:
#     639     n = operator.index(n)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\linalg\linalg.py:213, in _assert_stacked_square(*arrays)
#     211 m, n = a.shape[-2:]
#     212 if m != n:
# --> 213     raise LinAlgError('Last 2 dimensions of the array must be square')
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
tech_skills_enumerated = enumerate([s.name for s in tech_skills])
bad_skills = []
for i, skill in tech_skills_enumerated:
    try:
        tech_skills[i].calculate_components(P)
    except:
        print(f"Error processing skill: {skill}")
        bad_skills.append(tech_skills[i])
        continue

len(bad_skills)
# Out:
# Error processing skill: Linux Kernel
# Error processing skill: Fiber Optics
# Error processing skill: Technical Services
# Error processing skill: OmniPage
# Error processing skill: Network Routing
# Error processing skill: Information Assurance
# Error processing skill: IIS Manager
# Error processing skill: Media RSS
# Error processing skill: Bluetooth
# Error processing skill: Systems Engineering
# Error processing skill: SolarWinds
# Error processing skill: Bit.ly
# Error processing skill: HP 3000
# Error processing skill: HTML Application
# Error processing skill: Remote Server Management
# Error processing skill: ODB++
# Error processing skill: Deployment Project
# Error processing skill: System Design and Implementation
# Error processing skill: System Testing
# Error processing skill: Penetration Testing
# Error processing skill: AES3
# Error processing skill: Remote Data Services
# Error processing skill: Oracle Databases
# Error processing skill: Prolog (Programming Language)
# Error processing skill: Voicemail
# Error processing skill: Docker (Software)
# Error processing skill: Cryptography
# Error processing skill: Closed Loop
# Error processing skill: JGRASP
# Error processing skill: Mousemove
# Error processing skill: Communications Systems
# Error processing skill: Wireless Communications
# Error processing skill: Network Science
# Error processing skill: PostGIS
# Error processing skill: Database Architecture and Administration
# Error processing skill: Photo/Video Production and Technology
# Error processing skill: Software Requirements Specification
# Error processing skill: Military Operations
# Error processing skill: Network Storage
# Error processing skill: Web Portals
# Error processing skill: Microsoft Development Tools
# Error processing skill: OpenCL
# Error processing skill: Linux On Embedded Systems
# Error processing skill: Systems Analysis
# Error processing skill: Business Computer Systems
# Error processing skill: Satellite Communications
# Error processing skill: Microsoft SharePoint
# Error processing skill: Computer Science
# Error processing skill: HP Scannings
# Error processing skill: Data Management
# Error processing skill: Cadence SKILL
# Error processing skill: Enterprise Storage System
# Error processing skill: Authoring Software
# Error processing skill: Microsoft VPN
# Error processing skill: Scripting
# Error processing skill: Microcontrollers
# Error processing skill: Computer Hardware
# Error processing skill: Lynx
# Error processing skill: Data Acquisition
# Error processing skill: IP Code
# Error processing skill: Computer Programming
# Error processing skill: Security Engineering
# Error processing skill: Java (Programming Language)
# Error processing skill: FreeRTOS
# Error processing skill: Incident Management
# Error processing skill: LAN Administration
# Error processing skill: MMX
# Error processing skill: Interactive Web Content
# Error processing skill: Microsoft Internet Explorer
# Error processing skill: GUI Designer
# Error processing skill: Systems Design
# Error processing skill: Technical Management
# Error processing skill: WebRTC
# Error processing skill: Data Mapping
# Error processing skill: Data Protection Strategy
# Error processing skill: Web Application Security
# Error processing skill: Extranet
# Error processing skill: Microsoft Azure
# Error processing skill: IPCop
# Error processing skill: Development Testing
# Error processing skill: Mobile Phones
# Error processing skill: Installation
# Error processing skill: Embedded C
# Error processing skill: Computing Platforms
# Error processing skill: Gesture Recognition
# Error processing skill: Middleware
# Error processing skill: C++ (Programming Language)
# Error processing skill: ISO 2709
# Error processing skill: System Level Troubleshooting
# Error processing skill: ASIC Programming Language
# Error processing skill: Knockout Punches
# Error processing skill: Zooming
# Error processing skill: Windows Software
# Error processing skill: Software Engineering
# Error processing skill: Other Programming Languages
# Error processing skill: Business Integration Software
# Error processing skill: Disassembler
# Error processing skill: Service Development
# Error processing skill: Systems Administration
# Error processing skill: Amazon Web Services
# Error processing skill: Smtpd
# Error processing skill: RallyDev
# Error processing skill: Embedded Systems
# Error processing skill: Embedded Software
# Error processing skill: End-User Training And Support
# Error processing skill: Mobile Devices
# Error processing skill: DFSR
# Error processing skill: GSM Protocols
# Error processing skill: Integrated Development Environments
# Error processing skill: ACDSee
# Error processing skill: CAN Bus
# Error processing skill: Taxonomy
# Error processing skill: Documentum
# Error processing skill: IT Service Management
# Error processing skill: Pentaho Data Integration
# Error processing skill: Virtualization and Virtual Machines
# Error processing skill: Ethical Hacking
# Error processing skill: Cisco IOS
# Error processing skill: Apple IOS
# Error processing skill: Hyper-V
# Error processing skill: SAS/IML
# Error processing skill: Tslint
# Error processing skill: Transaction Data
# Error processing skill: Open MPI
# Error processing skill: Information Governance
# Error processing skill: Cellular Networks
# Error processing skill: Web Content Management
# Error processing skill: Cyber Security
# Error processing skill: Algorithm Design
# Error processing skill: Linux
# Error processing skill: Oracle Development
# Error processing skill: Security Administration
# Error processing skill: Warranty Analysis
# Error processing skill: Advanced Analytics
# Error processing skill: Mathematical Optimization
# Error processing skill: Optical Character Recognition (OCR)
# Error processing skill: Data Validation
# Error processing skill: Computer Vision
# Error processing skill: Minitab
# Error processing skill: Control Theories
# Error processing skill: Remote Sensing
# Error processing skill: Data Visualization
# Error processing skill: MATLAB
# Error processing skill: Algebra
# Error processing skill: Model-Based Design
# Error processing skill: Crystal Reports (Reporting Software)
# Error processing skill: Business Intelligence Software
# Error processing skill: Image Processing
# Error processing skill: Photogrammetry
# 149
